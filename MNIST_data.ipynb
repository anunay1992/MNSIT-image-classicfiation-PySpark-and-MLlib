# %% [markdown]
# The classic MNIST handwritten digit recognition dataset. It is from LeCun et al. (1998) and may be found under ["mnist" at the LibSVM dataset page](https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass.html#mnist).
#
# Our datasets are vectors of pixels representing images of handwritten digits.  For example:
#
# ![Image of a digit](http://training.databricks.com/databricks_guide/digit.png)
#
# - Our goal for our data is to learn how to recognize digits (0 - 9) from images of handwriting.

# %% [markdown]
# ### Step 1: Explore data
#
# Used databrick filesystem commands `%fs ls` to explore the data at `/databricks-datasets/mnist-digits/data-001` on databricks.
#  - list the files in the directory

# %%
# %fs ls /databricks-datasets/mnist-digits/data-001
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/mnist-digits/data-001/mnist-digits-test.txt</td><td>mnist-digits-test.txt</td><td>11671108</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/data-001/mnist-digits-train.txt</td><td>mnist-digits-train.txt</td><td>69430283</td></tr></tbody></table></div>

# %% [markdown]
# displayed the first two rows of the data in the training dataset

# %%
# %fs head dbfs:/databricks-datasets/mnist-digits/data-001/mnist-digits-train.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# ...

# %% [markdown]
# ### Step 2: Load the data

# %%
training_data = spark.read.format("libsvm").load("/databricks-datasets/mnist-digits/data-001/mnist-digits-train.txt").cache()
test_data = spark.read.format("libsvm").load("/databricks-datasets/mnist-digits/data-001/mnist-digits-test.txt").cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- label: double (nullable = true)
# -- features: vector (nullable = true)
#
# </div>

# %%
test_data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- label: double (nullable = true)
# -- features: vector (nullable = true)
#
# </div>

# %%
display(training_data.limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(test_data.limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
print("No. of rows in training data",training_data.count()) 
print("No. of rows in test data",test_data.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">No. of rows in training data 60000
# No. of rows in test data 10000
# </div>

# %% [markdown]
# displayed the first four images in the training data set.

# %%
import numpy as np
import matplotlib.image as mpimg
import math
import matplotlib.pyplot as plt

# a function to render images stored in the dataset.
def show_images(data):
  # Each image is supposed to be tuple.
  # the first element of the tuple is a 780 sparse vector, corresponding to features in the MNIST dataset.
  # the second element is an integer, corresponding to the label or predicted digit
  # in the following, we display the list of pictures in four-picture rows along with their labels.
  # don't show too many pictures with this function.

  # e.g. show_images([(r.features, r.label) for r in df.take(4)])
 
  fig = plt.figure()
  columns = 4
  rows = math.ceil(len(data)/4) # determine how many rows we need
  
  # ax enables access to manipulate each of subplots
  ax = []

  for i in range(len(data)):
      # the image is an array of 28x28 (=784) gray scale pixels. but the data is an 780 array. We need to pad it, 
      # convert it to float values, and reshape it to 28x28 matrices.
      img = np.array(np.pad(data[i][0],(0,784-len(data[i][0])),'constant',constant_values=(0,0)), dtype='float').reshape((28, 28))
      # create subplot and append to ax
      ax.append(fig.add_subplot(rows, 4, i+1) )
      ax[-1].set_title(str(int(data[i][1])))  # set title for the last image to its label.
      plt.imshow(img,cmap='gray') # render the image
      plt.axis('off') # turn off axies
  
  # display the images
  display(fig)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
show_images([(r.features, r.label) for r in training_data.take(4)])

# %%
# Images not coming when exporting the file as ipynb, so displaying the same image as in the databricks but using the saved imaage. 
from IPython.display import display, Image
display(Image(filename='/Users/anunaysmac/Home/MSBA Classes/Fall/PREDITIVE/github projects/_plots_c707fe26-a8bb-4cf2-bf4e-2698c9e2fbee.png'))

# %% [markdown]
# ###  Step 3. Train a DecisionTreeClassifier

# %%
from pyspark.ml.classification import DecisionTreeClassifier,RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DT = DecisionTreeClassifier(featuresCol='features',labelCol='label', seed = 0)
model = DT.fit(training_data)
prediction = model.transform(test_data)
prediction.select("label", "prediction").limit(10).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.0</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.0</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
evaluator= MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='label',
                                            metricName= "accuracy")
print("Accuracy :",evaluator.evaluate(prediction))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Accuracy : 0.6797
# </div>

# %% [markdown]
# ### Step 4: Visualize Results

# %% [markdown]
# ### 8 random correctly predicted images

# %%
show_images([(r.features,r.prediction) for r in (prediction.filter(prediction['label'] == prediction['prediction']).take(8))])

# %%
# Images not coming when exporting the file as ipynb, so displaying the same image as in the databricks but using the saved imaage. 
from IPython.display import display, Image
display(Image(filename='/Users/anunaysmac/Home/MSBA Classes/Fall/PREDITIVE/github projects/2.png'))

# %% [markdown]
# ### 8 random incorrectly predicted images

# %%
show_images([(r.features,r.prediction) for r in (prediction.filter(prediction['label'] != prediction['prediction']).take(8))])

# %%
# Images not coming when exporting the file as ipynb, so displaying the same image as in the databricks but using the saved imaage. 
from IPython.display import display, Image
display(Image(filename='/Users/anunaysmac/Home/MSBA Classes/Fall/PREDITIVE/github projects/3.png'))

# %% [markdown]
# ### Step 5: Improve the results using Random forest

# %%
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
RF = RandomForestClassifier(labelCol="label", featuresCol="features", seed = 0)
paramGrid = ParamGridBuilder().addGrid(RF.maxDepth, [15,20]).build()
evaluate = MulticlassClassificationEvaluator(metricName="accuracy",
labelCol='label', predictionCol='prediction')
CV = CrossValidator(estimator = RF, evaluator = evaluate ,
estimatorParamMaps = paramGrid, numFolds = 2)
modelCV = CV.fit(training_data)
predictionCV = modelCV.transform(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
predictionCV.select("label", "prediction").limit(10).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.0</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
print("Accuracy :",evaluate.evaluate(predictionCV))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Accuracy : 0.9582
# </div>

# %% [markdown]
# ### 8 random correctly predicted images

# %%
show_images([(r.features,r.prediction) for r in (predictionCV.filter(predictionCV['label'] == predictionCV['prediction']).take(8))])

# %%
# Images not coming when exporting the file as ipynb, so displaying the same image as in the databricks but using the saved imaage. 
from IPython.display import display, Image
display(Image(filename='/Users/anunaysmac/Home/MSBA Classes/Fall/PREDITIVE/github projects/4.png'))

# %% [markdown]
# ### 8 random incorrectly predicted images

# %%
show_images([(r.features,r.prediction) for r in (predictionCV.filter(predictionCV['label'] != predictionCV['prediction']).take(8))])

# %%
# Images not coming when exporting the file as ipynb, so displaying the same image as in the databricks but using the saved imaage. 
from IPython.display import display, Image
display(Image(filename='/Users/anunaysmac/Home/MSBA Classes/Fall/PREDITIVE/github projects/5.png'))

# %% [markdown]
# # Random forest in general gives much better accuracy than decision tree.
